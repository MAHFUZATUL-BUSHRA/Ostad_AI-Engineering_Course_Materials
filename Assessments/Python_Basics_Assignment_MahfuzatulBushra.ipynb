# %% [markdown]
# #Python Basics **Assignment** on Module 1

# %% [markdown]
# #Question 1: Basic Print

# %%
print("Welcome to Python Programming!")
print("I am learning the basics.")
# Out:
# Welcome to Python Programming!
# I am learning the basics.

# %% [markdown]
# #Question 2: Print with Variables

# %%
name = "Bushra"
age = 16

print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Bushra and I am 16 years old.

# %% [markdown]
# #Question 3: User Input

# %%
name = input("Enter your name: ")
language = input("Enter your favorite programming language: ")

print(f"Hello {name}, your favorite language is {language}.")
# Out:
# Enter your name: Bushra
# Enter your favorite programming language: Python
# Hello Bushra, your favorite language is Python.

# %% [markdown]
# #Question 4: Type Casting (String to Integer)

# %%
num1 = input("Enter first number: ")
num2 = input("Enter second number: ")

# Convert to integers
num1 = int(num1)
num2 = int(num2)

# Sum
total = num1 + num2
print(f"The sum is: {total}")
# Out:
# Enter first number: 4
# Enter second number: 6
# The sum is: 10

# %% [markdown]
# #Question 5: Simple Calculator

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

# Calculations
addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2

print(f"Addition: {addition}")
print(f"Subtraction: {subtraction}")
print(f"Multiplication: {multiplication}")
# Out:
# Enter first number: 48
# Enter second number: 9
# Addition: 57
# Subtraction: 39
# Multiplication: 432
