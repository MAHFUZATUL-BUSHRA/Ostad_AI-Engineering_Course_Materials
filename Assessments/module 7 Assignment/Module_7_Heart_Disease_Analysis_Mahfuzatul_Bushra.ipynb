# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c7da3de0-ef3c-459a-9199-fcccd210bae7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7da3de0-ef3c-459a-9199-fcccd210bae7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
df=pd.read_csv("heart.csv")

# %% [markdown]
# Question 1: Dataset Loading and Initial Exploration

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.shape
# Out:
# (1025, 14)

# %% [markdown]
# Question 2: Dataset Structure and Missing Value Analysis

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# ### No missing values found in dataset.

# %% [markdown]
# Question 3: Categorical Data Analysis

# %% [markdown]
# 1. Heart disease count (1 = heart disease, 0 = no disease)

# %%
df["target"].value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='target', data=df)
plt.title("Heart Disease Distribution (0 = No, 1 = Yes)")
plt.show()

# %% [markdown]
# 2. Gender count(1 = Male, 0 = Female)

# %%
df['sex'].value_counts()
# Out:
# sex
# 1    713
# 0    312
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='sex', data=df)
plt.title("Gender Distribution (0 = Female, 1 = Male)")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='sex', hue='target', data=df)
plt.title("Heart Disease by Gender")
plt.show()

# %% [markdown]
# Question 4: Data Selection Using iloc

# %% [markdown]
# 1. First 10 rows

# %%
df.iloc[:10]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %% [markdown]
# 2. age, sex, cholesterol columns

# %%
df.iloc[:,[0,1,4]]
# Out:
#       age  sex  chol
# 0      52    1   212
# 1      53    1   203
# 2      70    1   174
# 3      61    1   203
# 4      62    0   294
# ...   ...  ...   ...
# 1020   59    1   221
# 1021   60    1   258
# 1022   47    1   275
# 1023   50    0   254
# 1024   54    1   188
#
# [1025 rows x 3 columns]

# %% [markdown]
# 3. rows 20–30 & columns 0–4

# %%
df.iloc[20:31,0:5]
# Out:
#     age  sex  cp  trestbps  chol
# 20   60    1   2       140   185
# 21   67    0   0       106   223
# 22   45    1   0       104   208
# 23   63    0   2       135   252
# 24   42    0   2       120   209
# 25   61    0   0       145   307
# 26   44    1   2       130   233
# 27   58    0   1       136   319
# 28   56    1   2       130   256
# 29   55    0   0       180   327
# 30   44    1   0       120   169

# %% [markdown]
# Question 5: Data Filtering Using Conditions

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['age'], bins=20, kde=True)
plt.title("Age Distribution of Patients")
plt.show()

# %% [markdown]
# 1. Patients older than 50

# %%
df[df['age']>50]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1016   65    1   3       138   282    1        0      174      0      1.4
# 1017   53    1   0       123   282    0        1       95      1      2.0
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['chol'], bins=20, kde=True)
plt.title("Cholesterol Distribution")
plt.show()

# %% [markdown]
# 2. Heart disease + cholesterol > 240

# %%
df[(df['target']==1) & (df['chol']>240)]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 5      58    0   0       100   248    0        0      122      0      1.0
# 16     51    0   2       140   308    0        0      142      0      1.5
# 18     50    0   1       120   244    0        1      162      0      1.1
# 23     63    0   2       135   252    0        0      172      0      0.0
# 31     50    0   1       120   244    0        1      162      0      1.1
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 995    44    1   1       120   263    0        1      173      0      0.0
# 1004   51    0   2       140   308    0        0      142      0      1.5
# 1008   42    1   1       120   295    0        1      162      0      0.0
# 1011   45    1   1       128   308    0        0      170      0      0.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
#
#       slope  ca  thal  target
# 5         1   0     2       1
# ...

# %%
3. Count both conditions

# %%
len=len(df[(df['target']==1) & (df['chol']>240)])
len
# Out:
# 222
