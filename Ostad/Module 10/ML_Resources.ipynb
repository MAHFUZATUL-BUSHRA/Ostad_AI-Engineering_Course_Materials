# %% [markdown]
# [PDF: Andrew Ng Stanford Lecture Note CS229](https://cs229.stanford.edu/lectures-spring2022/main_notes.pdf)
#
# [Website: Machine Learning University](https://mlu-explain.github.io/)
#
# [Book: An Introduction to Statistical Learning](https://www.statlearning.com/)
#
# [Tutorial: Machine Learning](https://www.geeksforgeeks.org/machine-learning/machine-learning/)
